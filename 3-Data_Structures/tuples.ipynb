# %% [markdown]
# ### Tupeles
#
# Tuples are orderder collection of elements that is immutable

# %%
empty_tuple=()
print(empty_tuple)
print(type(empty_tuple))
# Out:
# ()
# <class 'tuple'>

# %%
lst=list()
tup=tuple()
print(type(lst))
print(type(tup))
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
numbers=tuple([1,2,2,3])
print(numbers)
# Out:
# (1, 2, 2, 3)

# %%
# Accessing TUPLE Element

numbers=(1,2,3,4,5)
numbers[1]

# All slicing methods are same as lists
# Out:
# 2

# %%
# Tuple Operations

numbers =(1,2,3,4,5)
mixed=("Pankaj",4,True)
connact = numbers+mixed
connact
# Out:
# (1, 2, 3, 4, 5, 'Pankaj', 4, True)

# %%
mixed*3
# Out:
# ('Pankaj', 4, True, 'Pankaj', 4, True, 'Pankaj', 4, True)

# %% [markdown]
# ### Immutable Nature Of Tuples

# %%
lst = (1,2,3)
print(lst)

# lst[0]=9
# print(lst)

# lst[0]+=1
# print(lst)
# Out:
# (1, 2, 3)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 7
#       2 print(lst)
#       4 # lst[0]=9
#       5 # print(lst)
# ----> 7 lst[0]+=1
#       8 print(lst)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### Tuples Method

# %%
print(numbers)
print(numbers.count(1))
print(numbers.index(4))
# Out:
# (1, 2, 3, 4, 5)
# 1
# 3

# %% [markdown]
# ### Pacaking and Unpackaing Tuples

# %%
# packed_tuple=1,"hello",3.14
# print(packed_tuple)
# a,b,c=packed_tuple
# print(a)
# print(b)
# print(c)


# Unpacking with *
num=(1,2,3,4)
first,*middle,last= num
print(first)
print(middle)
print(last)
# Out:
# 1
# [2, 3]
# 4
