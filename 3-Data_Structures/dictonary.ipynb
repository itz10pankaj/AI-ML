# %% [markdown]
# ##### Introduction to Dictionaries
#
# Dictionaries are unordered collections of items. They store data in key-value pairs.
# Keys must be unique and immutable (e.g., strings, numbers, or tuples), while values can be of any type.

# %%
student={}
print(type(student))
# Out:
# <class 'dict'>

# %%
student={"name":"Pankaj","age":22,"Role":"SDE"}
print(student)
print(student['name'])
print(student.get('name'))
print(student.get('last_name',"Not Available"))
student["Gender"]="Male"
student["name"]="Ayush"
print(student)
del student["Gender"]
print(student)
# Out:
# {'name': 'Pankaj', 'age': 22, 'Role': 'SDE'}
# Pankaj
# Pankaj
# Not Available
# {'name': 'Ayush', 'age': 22, 'Role': 'SDE', 'Gender': 'Male'}
# {'name': 'Ayush', 'age': 22, 'Role': 'SDE'}

# %% [markdown]
# ### Methods

# %%
student={"name":"Pankaj","age":22,"Role":"SDE"}
key=student.keys()
print(key)
values=student.values()
print(values)
items=student.items()
print(items)
print(type(items))


for item in items:
    print(item)
    print(type(item))
# Out:
# dict_keys(['name', 'age', 'Role'])
# dict_values(['Pankaj', 22, 'SDE'])
# dict_items([('name', 'Pankaj'), ('age', 22), ('Role', 'SDE')])
# <class 'dict_items'>
# Pankaj
# <class 'tuple'>
# 22
# <class 'tuple'>
# SDE
# <class 'tuple'>

# %%
student1={"name":"Pankaj"}
student2=student1  # Shallow Copy
student1["name"]="Ayush"
print(student1)
print(student2)
# Out:
# {'name': 'Ayush'}
# {'name': 'Ayush'}

# %%
students={
    "student1":{"name":"Krish","age":32},
    "student2":{"name":"Peter","age":35}
}
# print(students

## Iterating over nested dictionaries
for student_id,student_info in students.items():
    print(f"{student_id}:{student_info}")
    for key,value in student_info.items():
        print(f"{key}:{value}")
# Out:
# student1:{'name': 'Krish', 'age': 32}
# name:Krish
# age:32
# student2:{'name': 'Peter', 'age': 35}
# name:Peter
# age:35

# %%
## Dictionary Comphrehension
squares={x:x**2 for x in range(5)}
print(squares)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %%
## Practical Examples

## USe a dictionary to count he frequency of elements in list

numbers=[1,2,2,3,3,3,4,4,4,4]
frequency={}

for num in numbers:
    if num in frequency.keys():
        frequency[num] +=1
    else:
        frequency[num] =1
print(frequency)
# Out:
# {1: 1, 2: 2, 3: 3, 4: 4}

# %%
## Merge Two Dictonaires

dict1={"a":1,"b":2}
dict2={"b":3,"c":4}
merged_dict={**dict1,**dict2}
print(merged_dict)
# Out:
# {'a': 1, 'b': 3, 'c': 4}
