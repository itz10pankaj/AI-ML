# %%
from math import *
sqrt(45)
# Out:
# 6.708203932499369

# %%
import datetime as dt
print(dt.datetime.now())
# Out:
# 2026-01-09 22:57:48.048719

# %%
from random import randint
print(randint(1,100))
# Out:
# 57

# %%
try :
    import hii
except ImportError as e:
    print(f"{e}")
# Out:
# No module named 'hii'

# %%
import os

os.mkdir("new_dic")
print(os.listdir('.'))
os.rmdir("new_dic")
print(os.listdir('.'))
# Out:
# ['1-import.ipynb', '2-Library.ipynb', 'assgnmen.ipynb', 'destination.txt', 'example.csv', 'new_dic', 'package', 'source.txt', 'test.py', 'test_dir']
# ['1-import.ipynb', '2-Library.ipynb', 'assgnmen.ipynb', 'destination.txt', 'example.csv', 'package', 'source.txt', 'test.py', 'test_dir']

# %%
import sys

print(f"Python version: {sys.version}")
print(f"Command-line arguments: {sys.argv}")
# Out:
# Python version: 3.12.0 | packaged by Anaconda, Inc. | (main, Oct  2 2023, 17:20:38) [MSC v.1916 64 bit (AMD64)]
# Command-line arguments: ['e:\\Python\\venv\\Lib\\site-packages\\ipykernel_launcher.py', '--f=c:\\Users\\pgarg\\AppData\\Roaming\\jupyter\\runtime\\kernel-v3cfc469c1db0c0e233ff5114a69dbc840e203caec.json']

# %%
from datetime import datetime,timedelta,date

today=datetime.now()
print(today)
pre=today+timedelta(days=-100)
print(pre)

given_date = date(2022, 1, 1)
print(f"Day of the week for 2022-01-01: {given_date.strftime('%A')}")
# Out:
# 2026-01-09 23:04:43.272315
# 2025-10-01 23:04:43.272315
# Day of the week for 2022-01-01: Saturday
