# %% [markdown]
# ### If/Else/IfElse

# %%
a =10
b=int(input("Enter value of b:"))
if(a==5):
    print(" equal than 5")
elif (a>5):
    if(b==6):
        print("equal to 6")
        print("greater to 5")
    elif(True):
        print("greater to 5")
else:
    print("lesser than 5")
# Out:
# greater to 5

# %%
year = int(input("Enter year: "))

if(year %4 ==0 and year %100 !=0):
    print(f"{year} is a lead year")
elif(year % 400 ==0):
    print(f"{year} is a lead year")
else:
    print(f"{year} is not a lead year")
# Out:
# 2004 is a lead year
