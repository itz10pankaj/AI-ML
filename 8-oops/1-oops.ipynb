# %% [markdown]
# ####  Classes and Objects
# Object-Oriented Programming (OOP) is a programming paradigm that uses "objects" to design applications and computer programs. OOP allows for modeling real-world scenarios using classes and objects.

# %%
class Car:
    pass

audi = Car()
bmw = Car()

print(type(audi))
print(audi)
# Out:
# <class '__main__.Car'>
# <__main__.Car object at 0x00000271A035F8C0>

# %%
audi.windows = 4
print(audi.windows)
# Out:
# 4

# %%
tata=Car()
tata.door=3
print(tata.windows)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 tata=Car()
#       2 tata.door=3
# ----> 3 print(tata.windows)
#
# AttributeError: 'Car' object has no attribute 'windows'

# %%
class student:
    name = "Pankaj"

student1=student()
print(student1.name)
student1.name="hlo"
print(student1.name)
student2=student()
print(student2.name)
# Out:
# Pankaj
# hlo
# Pankaj

# %%
dir(tata)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'door']

# %%
### Instance Variable and Methods
class Dog:
    ## constructor
    def __init__(self,name,age):
        self.name = name
        self.age = age
dog1=Dog("Buddy",3)
print(dog1)
print(dog1.age)
print(dog1.name)
# Out:
# <__main__.Dog object at 0x00000271A0533230>
# 3
# Buddy

# %%
## Define a class with instance methods
class Dog:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    
    def bark(self):
        print(f"{self.name} says woof")


dog1=Dog("Buddy",3)
dog1.bark()
dog2=Dog("Lucy",4)
dog2.bark()

# %%
## design a Bank Account

class Bank:
    def __init__(self,owner,balance):
        self.owner = owner
        self.balance =  balance
    def checkbalance(self):
        return self.balance
    def credit(self,amount):
        self.balance = self.balance + amount
        return "Success"
    def debit(self,amount):
        if amount > self.balance:
            return "Insufficent Amount"
        else:
            self.balance -= amount
            return "Success"
        
account=Bank("Pankaj",5000)
print(account.checkbalance())
print(account.credit(2000))
print(account.checkbalance())
print(account.debit(8000))
print(account.debit(3000))
print(account.checkbalance())
# Out:
# 5000
# Success
# 7000
# Insufficent Amount
# Success
# 4000
